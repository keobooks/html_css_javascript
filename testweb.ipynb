# %% [markdown]
# # 웹페이지 작성 학습

# %% [markdown]
# ## 웹페이지 작성 소스

# %%
# %%html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Festival</title>
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/css/bootstrap.min.css" rel="stylesheet">
#     <link rel="stylesheet" href="css/style.css">
# </head>
# <body>
#     <!-- 네비게이션 바 -->
#     <nav class="navbar navbar-expand-lg navbar-light bg-light">
#         <div class="container-fluid">
#             <a class="navbar-brand" href="#">Festival</a>
#             <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
#                 <span class="navbar-toggler-icon"></span>
#             </button>
#             <div class="collapse navbar-collapse" id="navbarNav">
#                 <ul class="navbar-nav ms-auto">
#                     <li class="nav-item">
#                         <a class="nav-link active" aria-current="page" href="#">Home</a>
#                     </li>
#                     <li class="nav-item">
#                         <a class="nav-link" href="ticket.html">Tickets</a>
#                     </li>
#                     <li class="nav-item">
#                         <a class="nav-link" href="gallery.html">Gallery</a>
#                     </li>
#                     <li class="nav-item">
#                         <a class="nav-link" href="contact.html">Contact</a>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </nav>
#
#     <!-- 메인 배너 -->
#     <section class="hero bg-dark text-white text-center p-5">
#         <div class="container">
#             <h1 class="display-4">Join the Festival!</h1>
#             <p class="lead">Experience the ultimate festival of music, art, and culture.</p>
#             <a href="ticket.html" class="btn btn-primary">Buy Tickets</a>
#         </div>
#     </section>
#
#     <!-- 페스티벌 소개 -->
#     <section class="about py-5">
#         <div class="container">
#             <div class="row">
#                 <div class="col-md-6">
#                     <h2>About the Festival</h2>
#                     <p>The festival offers an unforgettable experience with live music, amazing performances, and unique art displays. Don't miss out on the fun and excitement!</p>
#                 </div>
#                 <div class="col-md-6">
#                     <img src="img/festival.jpg" class="img-fluid" alt="Festival">
#                 </div>
#             </div>
#         </div>
#     </section>
#
#     <!-- 일정 섹션 -->
#     <section class="schedule py-5 bg-light">
#         <div class="container text-center">
#             <h2>Festival Schedule</h2>
#             <p>Here are the dates and events you can't miss!</p>
#             <ul class="list-group">
#                 <li class="list-group-item">Day 1: Opening Ceremony</li>
#                 <li class="list-group-item">Day 2: Live Performances</li>
#                 <li class="list-group-item">Day 3: Art Exhibitions</li>
#             </ul>
#         </div>
#     </section>
#
#     <!-- 푸터 -->
#     <footer class="bg-dark text-white text-center py-3">
#         <p>&copy; 2024 Festival. All rights reserved.</p>
#     </footer>
#
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/js/bootstrap.bundle.min.js"></script>
# </body>
# </html>

# %% [markdown]
# ## html태그 연습

# %%
# %%html
#
# <h1>Hello, Colab!</h1>
# <p>This is a paragraph.</p>

# %% [markdown]
# # HTML5&CSS3 그리고 JavaScript책 소스

# %% [markdown]
# ## 2장 코드를 작성하고 실행하는 개발환경 설정

# %%
# %%html
# <!--index.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>처음으로 작성하는 HTML페이지</title>
# </head>
# <body>
#   <p>처음으로 작성하는 HTML페이지
# </body>
# </html>

# %%
# %%html

# %% [markdown]
# ## 3장 문서를 구조화하는 HTML

# %% [markdown]
# ### 01 HTML 개요 및 기본태그

# %%
# %%html
# <!--view.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>test</title>
# </head>
# <body>
#   <p>연습test</p>
# </body>
# </html>

# %%
# %%html
# <!--htmltags01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>문단 구분 및 글꼴 속성 태그 사용</title>
# </head>
# <body>
#   <p>
#     <b>IoT(Internet of Things, 사물인터넷)</b><br>
#     사물에 센서와 통신 기능을 내장하여 인터넷에 연결하는 기술.<br>
#     네트워크를 사용하기 때문에 해킹의 위험이 높음.<br>
#     보안이 필수임.<br>
#   </p>
#   <p>
#     <b><i>3D printing(3D 프린팅)</i></b><br>
#     3차원 물체를 만들어내는 제조 기술.<br>
#     컴퓨터로 제어되기 때문에 형태를 만들 수 있음. <br>
#     다른 제조 기술에 비해 쉽게 사용할 수 있음.
#   </p>
# </body>
# </html>

# %%
# %%html
# <!--htmltags02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>이미지 포함 페이지</title>
# </head>
# <body>
#   <p>
#     <img src="https://probemedia.github.io/studyhtml5/ch03/p1_s.png">이미지 1
#   </p>
#   <p>
#     <img src="https://probemedia.github.io/studyhtml5/ch03/p2_s.png">이미지 2
#   </p>
# </body>
# </html>

# %%
# %%html
# <!--htmltags03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>페이지 이동</title>
# </head>
# <body>
#   <a href="https://probemedia.github.io/studyhtml5/ch03/img_cont.html">
#      <img src="https://probemedia.github.io/studyhtml5/ch03/picture2.png" width="60" height="70"></a>
# </body>
# </html>

# %%
# %%html
# <!--htmltags04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>테이블 사용</title>
# </head>
# <body>
#   <table border="1">
#      <tr>
#        <td>이미지 </td>
#        <td>이미지 파일명 </td>
#      </tr>
#      <tr>
#        <td><img src="https://probemedia.github.io/studyhtml5/ch03/picture1.png"
#             width="90" height="60" border="0"></td>
#        <td>picture1.png</td>
#      </tr>
#      <tr>
#        <td><img src="https://probemedia.github.io/studyhtml5/ch03/picture2.png"
#            width="90" height="60" border="0"></td>
#        <td>picture2.png</td>
#      </tr>
#    </table>
# </body>
# </html>

# %%
# %%html
# <!--.html-->
# <div id="header">
#   <h1>우리기관</h1>
#   <div id="nav">
#     <ul>
#       <li><a href="#">기관소개</a></li>
#       <li><a href="#">행정안내</a></li>
#       <li><a href="#">정보공개</a></li>
#     </ul>
#   </div>
# </div>
# <div id="content">
#   <p>내용</p>
# </div>
# <div id="footer">
#   <p>찾아오시는 길</p>
# </div>

# %% [markdown]
# ### 02 HTML5 문서구조 및 주요태그

# %%
# %%html
# <!--documentArea.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>Insert title here</title>
# </head>
# <body>
#   <div id="page">
#     <header id="header">
#       <p>헤더영역</p>
#       <nav id="menu">
#         <a href="#">회사소개</a>
#         <a href="#">상품소개</a>
#       </nav>
#     </header>
#     <section id="content">내용영역</section>
#     <aside id="sub">사이드바</aside>
#     <footer id="footer">푸터영역</footer>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_sy03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>figure, figcaption 태그 연습</title>
# </head>
# <body>
#   <div>
#     <figure>
#      <img src="https://probemedia.github.io/studyhtml5/ch03/notebook02_s.png" alt="awesome notebook">
#      <figcaption>핸드메이드 awesome notebook</figcaption>
#     </figure>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_sy04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>mark, meter, progress 태그 연습</title>
# </head>
# <body>
# <div>
#   <p>본 웹사이트의 <mark>고객센터</mark> 입니다.</p>
#   </div>
#   <div>
#     <p>측정값 :
#     <meter value="5" min="1" max="10">1~10사이에서 5</meter></p>
#     <p>디스크 사용량 :
#     <meter value="0.7">70%</meter></p>
#   </div>
#   <div>
#     <p>작업진행상태:
#     <progress value="30" max="100"></progress></p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>label 태그 연습</title>
# </head>
# <body>
#   <form>
#     <label for="name">이름</label>
#     <input type="text" id="name"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>fieldset 태그 연습</title>
# </head>
# <body>
#   <form>
#     <fieldset>
#       <legend>취미</legend>
#       <input type="checkbox" name="h1" id="h1"/>
#       <label for="h1" >낮잠</label>
#       <input type="checkbox" name="h2" id="h2"/>
#       <label for="h2">TV시청</label>
#     </fieldset>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 텍스트 필드 연습1</title>
# </head>
# <body>
#   <form>
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" required
#       placeholder="honhkd@kingdora.com"/><br>
#     <label for="name">이름</label>
#     <input type="text" id="name" name="name" required
#       placeholder="홍길동"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 텍스트 필드 연습2</title>
# </head>
# <body>
#   <form>
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" maxlength="12" size="20"
#       placeholder="hong@kingdora.com" required/><br>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 텍스트 필드 연습3</title>
# </head>
# <body>
#   <form>
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" required/><br>
#     <input type="submit" value="전송">
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 패스워드 필드 연습1</title>
# </head>
# <body>
#   <form>
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" required/><br>
#     <label for="pass">비밀번호</label>
#     <input type="password" id="pass" name="pass" required/><br>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf07.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 패스워드 필드 연습2</title>
# </head>
# <body>
#   <form>
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" maxlength="20" size="30"
#      pattern="[0-9A-Za-z@.]{6,20}" autofocus required/><br>
#     <label for="pass">비밀번호</label>
#     <input type="password" id="pass" name="pass" maxlength="12" size="30"
#      pattern="[0-9A-Za-z#@$%^*]{6,12}" required/><br>
#     <input type="submit" value="전송">
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf08.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 체크박스 연습</title>
# </head>
# <body>
#   <form>
#     <fieldset>
#       <legend>취미</legend>
#       <input type="checkbox" name="h1" id="h1" value="a1" checked/>
#       <label for="h1" >낮잠</label>
#       <input type="checkbox" name="h1" id="h2" value="a2"/>
#       <label for="h2" >TV시청</label>
#       <input type="checkbox" name="h1" id="h3" value="a3"/>
#       <label for="h3" >만화보기</label><br>
#       <input type="submit" value="전송">
#     </fieldset>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf09.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 라디오버튼 연습</title>
# </head>
# <body>
#   <form>
#     <fieldset>
#       <legend>성별</legend>
#       <input type="radio" name="g" id="g" value="m" checked/>
#       <label for="g">남</label>
#       <input type="radio" name="g" id="g" value="f"/>
#       <label for="g">여</label>
#       <input type="submit" value="전송">
#     </fieldset>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf10.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 파일 선택기 연습1</title>
# </head>
# <body>
#   <form name="form1" action="#" method="post" enctype="multipart/form-data">
#     <label for="id">파일선택:</label>
#     <input type="file" id="file1" name="file1"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf11.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 파일 선택기 연습2</title>
# </head>
# <body>
#   <form name="form1" action="#" method="post" enctype="multipart/form-data">
#     <label for="id">파일선택:</label>
#     <input type="file" id="file1" name="file1" multiple/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf12.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - submit버튼 연습1</title>
# </head>
# <body>
#   <form action="submitPro.jsp">
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" required/><br>
#     <input type="submit" value="전송">
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf13.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - submit버튼 연습2</title>
# </head>
# <body>
#   <form method="post" action="submitPro2.jsp">
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" required/><br>
#     <label for="pass">비밀번호</label>
#     <input type="password" id="pass" name="pass" required/><br>
#     <input type="submit" value="전송">
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf14.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - reset버튼 연습</title>
# </head>
# <body>
#   <form>
#     <label for="id">아이디</label>
#     <input type="text" id="id" name="id" required/><br>
#     <label for="pass">비밀번호</label>
#     <input type="password" id="pass" name="pass" required/><br>
#     <label for="name">이름</label>
#     <input type="text" id="name" name="name" required/><br>
#     <input type="reset" value="취소">
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf15.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - button버튼 연습</title>
# </head>
# <body>
#   <form>
#     <input type="button" value="작업처리" onclick="alert('작업처리')">
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf16.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 이메일 필드 연습</title>
# </head>
# <body>
#   <form>
#     <label for="email">이메일</label>
#     <input type="email" id="email" name="email"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf17.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - URL 필드 연습</title>
# </head>
# <body>
#   <form>
#     <label for="url">사이트 주소</label>
#     <input type="url" id="url" name="url"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf18.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 전화번호 필드 연습</title>
# </head>
# <body>
#   <form>
#     <label for="tel">전화번호</label>
#     <input type="tel" id="tel" name="tel"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf19.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 숫자 필드 연습</title>
# </head>
# <body>
#   <form>
#     <label for="num">나이</label>
#     <input type="number" id="num" name="num" min="1" max="99" value="20"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf20.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 숫자 범위 연습</title>
# </head>
# <body>
#   <form>
#     <label for="temp">온도</label>
#     <input type="range" id="temp" name="temp" min="-20" max="70"
#       value="20" step="1"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf21.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 날짜 선택 연습</title>
# </head>
# <body>
#   <form>
#     <label for="day">오늘날짜</label>
#     <input type="date" id="day" name="day"
#       min="2023-01-01" max="2025-12-31" value="2023-03-10"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf22.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 시간 선택 연습</title>
# </head>
# <body>
#   <form>
#     <label for="now">현재시간</label>
#     <input type="time" id="now" name="now" value="09:00"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf24.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 검색 필드 연습</title>
# </head>
# <body>
#   <form>
#     <label for="search">검색어</label>
#     <input type="search" id="search" name="search" placeholder="검색어입력"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf25.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>input 태그 - 색상 필드 연습</title>
# </head>
# <body>
#   <form>
#     <label for="color">색상 선택</label>
#     <input type="color" id="color" name="color"/>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf26.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>select 태그 - 드롭 다운 리스트 연습</title>
# </head>
# <body>
#   <form>
#     <label for="lang">언어선택</label>
#     <select name="lang" id="lang">
#       <option value="ko">한국어
#       <option value="en" selected>영어
#       <option value="ch">중국어
#     </select>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf27.html-->
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>textarea 태그 - 텍스트에리어 연습</title>
# </head>
# <body>
#   <form>
#     <label for="lang">내용</label>
#     <textarea name="lang" id="lang" rows="5" cols="30"></textarea>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_wf28.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>button 태그 - 버튼 연습</title>
# </head>
# <body>
#   <form>
#     <button id="result">결과처리</button>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_md01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>audio 태그 - 오디오 재생 연습</title>
# </head>
# <body>
#   <div>
#     <p>오디오 파일 재생</p>
#     <audio controls>
#       <source src = "https://probemedia.github.io/studyhtml5/ch03/play4.mp3" type = "audio/mpeg"/>
#     </audio>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_md02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>video 태그 - 비디오 재생 연습</title>
# </head>
# <body>
#   <div>
#     <p>비디오 파일 재생</p>
#     <video width="320" height="240" controls>
#       <source src = "https://probemedia.github.io/studyhtml5/ch03/sea.mp4" type = "video/mp4">
#     </video>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_md03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>embed 태그 - 플러그인 콘텐츠 표시 연습</title>
# </head>
# <body>
#   <div>
#     <p>플러그인 콘텐츠 표시</p>
#     <embed src="https://probemedia.github.io/studyhtml5/ch03/page_s.jpg" width="150" height="100">
#     <embed src="https://probemedia.github.io/studyhtml5/ch03/view.html" width="100" height="50">
#     <embed src="https://probemedia.github.io/studyhtml5/ch03/sea.mp4" width="200" height="150">
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_md04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>object 태그 - 내장 객체를 사용한 콘텐츠 표시 연습</title>
# </head>
# <body>
#   <div>
#     <p>내장 객체를 사용한 콘텐츠 표시</p>
#     <object data="https://probemedia.github.io/studyhtml5/ch03/page_s.jpg" width="150" height="100"></object>
#     <object data="https://probemedia.github.io/studyhtml5/ch03/view.html" width="100" height="50"></object>
#     <object data="https://probemedia.github.io/studyhtml5/ch03/sea.mp4" width="200" height="150"></object>
#     <object data="https://probemedia.github.io/studyhtml5/ch03/initialization_parameter.pdf"></object>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_md05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>iframe 태그 - 유튜브 동영상 표시 연습</title>
# </head>
# <body>
#   <div>
#     <section>
#       <h2>Everything Is AWESOME!!!</h2>
#       <p> -- The LEGO® Movie -- Tegan and Sara feat. The Lonely Island</p>
#       <iframe width="560" height="315"
#       src="https://www.youtube.com/embed/StTqXEQ2l-Y?si=heBdzbyiBm3juDxK"
#       title="YouTube video player" frameborder="0"
#       allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share"
#       referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#     </section>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--htmltags_md06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>svg 태그 - svg 연습</title>
# </head>
# <body>
#   <div>
#     <svg width="300" height="100">
#      <rect width="300" height="100" stroke="black" stroke-width="4" fill="gray" />
#     </svg>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--.html-->

# %% [markdown]
# ## 4장 태그를 표현하는 CSS와 Advanced CSS

# %% [markdown]
# ### 01 CSS 개요 및 기본사용법

# %%
# %%html
# <!--css_01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>스타일 시트를 태그의 style 속성에 작성 연습</title>
# </head>
# <body>
#   <div>
#     <p style="color:blue;">네셔널 리그</p>
#     <p style="color:red;">퍼시픽 리그</p>
#     <p style="color:#000000;font-weight:bold;">KBO 한국 시리즈</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>스타일 시트를 HTML문서 내에 포함해서 작성 연습</title>
# <style>
#   div{
#     width    :  200px;
#     height   :  100px;
#     background-color : #ddefff;
#   }
# </style>
# </head>
# <body>
#   <div>
#     <p>네셔널 리그</p>
#     <p>퍼시픽 리그</p>
#     <p>KBO 한국 시리즈</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>스타일 시트를 별도의 파일로 작성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_03.css"/>
# </head>
# <body>
#   <div>
#     <p>야구</p>
#     <p>축구</p>
#     <p>농구</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>실렉터 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_04.css"/>
# </head>
# <body>
#   <div>
#     <p class="area">마블 히어로즈</p>
#     <p>DC 히어로즈</p>
#   </div>
#   <div id="display">
#     <p class="area">WOW</p>
#     <p>StarCraft</p>
#   </div>
# </body>
# </html>

# %% [markdown]
# ### 02 CSS의 주요속성과 값

# %%
# %%html
# <!--css_p01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 color, background-color속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p01.css"/>
# </head>
# <body>
#   <div>
#     <p>마블 히어로즈</p>
#     <p>DC 히어로즈</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 background-image속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p02.css"/>
# </head>
# <body>
#   <div>
#     <p>프로토스</p>
#     <p>저그</p>
#     <p>테란</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 font속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p03.css"/>
# </head>
# <body>
#   <div>
#     <p>프로토스</p>
#     <p>저그</p>
#     <p class="s2">테란</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 텍스트(Text)관련 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p04.css"/>
# </head>
# <body>
#   <div>
#     <p class="normal">Khalani is the language "spoken" (via telepathy) by the protoss.
#    The language's written form is glyph-based.</p>
#     <p class="pre">Khalani is the language "spoken" (via telepathy) by the protoss.
#    The language's written form is glyph-based.</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 border관련 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p05.css"/>
# </head>
# <body>
#   <div>
#     <table class="b1">
#      <tr class="b1">
#         <td class="b1">1</td>
#         <td class="b1">2</td>
#         <td class="b1">3</td>
#      </tr>
#     </table>
#     <table class="b2">
#      <tr class="b2">
#         <td class="b2">1</td>
#         <td class="b2">2</td>
#         <td class="b2">3</td>
#      </tr>
#     </table>
#     <table class="b3">
#      <tr class="b3">
#         <td class="b3">1</td>
#         <td class="b3">2</td>
#         <td class="b3">3</td>
#      </tr>
#     </table>
#     <table class="b4">
#      <tr class="b4">
#         <td class="b4">1</td>
#         <td class="b4">2</td>
#         <td class="b4">3</td>
#      </tr>
#     </table>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 border관련 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p06.css"/>
# </head>
# <body>
#   <div>
#    <p>데스크탑 애플리케이션은 CD 또는 웹 사이트에서 다운로드해서 컴퓨터에 설치되는 방식의 프로그램들로, 이들은 인터넷을 이용해 업데이트하기도 하지만 어플리케이션 실행 코드(프로그램)는 개개인의 컴퓨터상에 상주해 있다.
#    </p>
#    <p>웹 어플리케이션은 웹 서버 상에서 실행되며 웹 브라우저 상에서 접속된다. 어플리케이션 실행 코드가 웹 서버상에 존재한다.
#    </p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p07.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 display 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p07.css"/>
# </head>
# <body>
#   <div>
#     <button>버튼1</button>
#     <button>버튼2</button>
#     <button>버튼3</button>
#   </div>
#   <div>
#     <button class="block">버튼1</button>
#     <button class="block">버튼2</button>
#     <button class="block">버튼3</button>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p08.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 visible 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p08.css"/>
# </head>
# <body>
#   <div class="visible">
#    <img id="im1" src="https://probemedia.github.io/studyhtml5/images/picture1.png"/>
#    <p>웹 어플리케이션은 웹 서버 상에서 실행되며 웹 브라우저 상에서 접속된다. 어플리케이션 실행 코드가 웹 서버상에 존재한다.</p>
#   </div>
#   <div class="hidden">
#    <img id="im1" src="https://probemedia.github.io/studyhtml5/images/picture2.png"/>
#    <p class="visible">웹 어플리케이션은 웹 서버 상에서 실행되며 웹 브라우저 상에서 접속된다. 어플리케이션 실행 코드가 웹 서버상에 존재한다.</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p09.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 position속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p09.css"/>
# </head>
# <body>
#   <div>
#    <img id="im1" src="https://probemedia.github.io/studyhtml5/images/space.png"/>
#    <p>웹 어플리케이션은 웹 서버 상에서 실행되며 웹 브라우저 상에서 접속된다. 어플리케이션 실행 코드가 웹 서버상에 존재한다.</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p10.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 z-index속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p10.css"/>
# </head>
# <body>
#   <div>
#     <img id="img1" src="https://probemedia.github.io/studyhtml5/images/picture1.png"/>
#     <img id="img2" src="https://probemedia.github.io/studyhtml5/images/picture2.png"/>
#     <img id="img3" src="https://probemedia.github.io/studyhtml5/images/picture3.png"/>
#     <img id="img4" src="https://probemedia.github.io/studyhtml5/images/picture4.png"/>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p11.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 float속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p11.css"/>
# </head>
# <body>
#   <div>
#     <img id="img1" src="https://probemedia.github.io/studyhtml5/images/picture1.png"/>
#     <img id="img2" src="https://probemedia.github.io/studyhtml5/images/picture2.png"/>
#     <img id="img3" src="https://probemedia.github.io/studyhtml5/images/picture3.png"/>
#     <img id="img4" src="https://probemedia.github.io/studyhtml5/images/picture4.png"/>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css_p12.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 float/clear속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_p12.css"/>
# </head>
# <body>
# <div id="wrapper">
#   <header>헤더 입니다.</header>
#   <section>
#     <img id="img1" src="https://probemedia.github.io/studyhtml5/images/picture1.png"/>
#     <img id="img2" src="https://probemedia.github.io/studyhtml5/images/picture2.png"/>
#     <img id="img3" src="https://probemedia.github.io/studyhtml5/images/picture3.png"/>
#     <img id="img4" src="https://probemedia.github.io/studyhtml5/images/picture4.png"/>
#   </section>
#   <aside>사이드 바입니다.</aside>
#   <footer>푸터 입니다.</footer>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--.html-->

# %% [markdown]
# ### 03 미디어쿼리

# %%
# %%html
# <!--css_m01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS의 미디어쿼리 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css_m01.css"/>
# </head>
# <body>
#   <div>
#    <p>미디어쿼리 연습</p>
#   </div>
# </body>
# </html>

# %% [markdown]
# ### 04 Advanced CSS

# %%
# %%html
# <!--css3_01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 border-radius 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_01.css"/>
# </head>
# <body>
#   <div id="displayArea">
#     <h3>StarCraft II</h3>
#     <ul>
#       <li>Wings of Liberty
#       <li>Heart of the Swarm
#       <li>Legacy of the Void
#     </ul>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 box-shadow 속성 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_02.css"/>
# </head>
# <body>
#   <div class="boxshadow">그림자 효과</div>
# </body>
# </html>

# %%
# %%html
# <!--css3_03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 투명도를 추가한 색상 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_03.css"/>
# </head>
# <body>
#   <div>
#     <p class="rgba"></p>
#     <p class="hsla"></p>
#     <p class="opacity"></p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 border-image 속성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_04_2.css"/>
# </head>
# <body>
#   <div>
#     <p class="borderimage1">url(https://probemedia.github.io/studyhtml5/images/b1.png) 30 round</p>
#     <p class="borderimage2">url(https://probemedia.github.io/studyhtml5/images/b1.png) 30 repeat</p>
#     <p class="borderimage3">url(https://probemedia.github.io/studyhtml5/images/b1.png) 30 stretch</p>
#     <p class="borderimage4">url(https://probemedia.github.io/studyhtml5/images/b1.png) 10 round</p>
#     <p class="borderimage5">url(https://probemedia.github.io/studyhtml5/images/b1.png) 50% round</p>
#   </div>
#   <div class="bg">
#     <p class="borderimage1">url(https://probemedia.github.io/studyhtml5/images/b1.png) 30 round</p>
#     <p class="borderimage2">url(https://probemedia.github.io/studyhtml5/images/b1.png) 30 repeat</p>
#     <p class="borderimage3">url(https://probemedia.github.io/studyhtml5/images/b1.png) 30 stretch</p>
#     <p class="borderimage4">url(https://probemedia.github.io/studyhtml5/images/b1.png) 10 round</p>
#     <p class="borderimage5">url(https://probemedia.github.io/studyhtml5/images/b1.png) 50% round</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 배경이미지 중첩 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_05.css"/>
# </head>
# <body>
#   <div>
#     <p>안시성 전투는 645년(보장왕 4년)에 고구려를 침략한 당나라 군대를 안시성에서 물리치고 고구려가 승리한 싸움이다.</p>
#   </div>
#
# </body>
# </html>

# %%
# %%html
# <!--css3_06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 background-size속성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_06.css"/>
# </head>
# <body>
#   <div class="bgimg1">
#     <p>원래이미지</p>
#   </div>
#   <div class="bgimg2">
#     <p>150px X 100px</p>
#   </div>
#   <div class="bgimg3">
#     <p>contain</p>
#   </div>
#   <div class="bgimg4">
#     <p>cover</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_07.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 text-shadow속성 연습</title>
# <style>
#   p{
#     text-shadow : 5px 5px 5px #888888;
#   }
# </style>
# </head>
# <body>
#   <div>
#     <p>그림자 효과(text-shadow)</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_08.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 linear-gradient, radial-gradient속성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_08.css"/>
# </head>
# <body>
#   <div id="g1"></div>
#   <div id="g2"></div>
#   <div id="g3"></div>
#   <div id="g4"></div>
# </body>
# </html>

# %%
# %%html
# <!--css3_09.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 transform속성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_09.css"/>
# </head>
# <body>
#   <div>원래 사각형</div>
#   <div id="t1">(10,10)이동</div>
#   <div id="t2">45도 회전</div>
#   <div id="t3">가로1배,세로 0.5배</div>
#   <div id="t4">x축 20도,y축 10도</div>
# </body>
# </html>

# %%
# %%html
# <!--css3_10.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 transition 속성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_10.css"/>
# </head>
# <body>
#   <div>마우스포인터를 여기에!</div>
# </body>
# </html>

# %%
# %%html
# <!--css3_11.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 애니메이션 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_11.css"/>
# </head>
# <body>
#   <div>애니메이션</div>
# </body>
# </html>

# %%
# %%html
# <!--css3_12.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 filter 속성 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_12.css"/>
# </head>
# <body>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png">
#     <figcaption>원래 이미지</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="blur">
#     <figcaption>blur(3px)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="brightness">
#     <figcaption>brightness(150%)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="contrast">
#     <figcaption>contrast(200%)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="drop-shadow">
#     <figcaption>drop-shadow(5px 5px 5px gray)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/mages/tree.png" class="grayscale">
#     <figcaption>grayscale(100%)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="hue-rotate">
#     <figcaption>hue-rotate(180deg)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="invert">
#     <figcaption>invert(100%)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="opacity">
#     <figcaption>opacity(50%)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="saturate">
#     <figcaption>saturate(300%)</figcaption>
#   </figure>
#   <figure>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="sepia">
#     <figcaption>sepia(100%)</figcaption>
#   </figure>
# </body>
# </html>

# %%
# %%html
# <!--css3_13.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 라운드 이미지 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_13.css"/>
# </head>
# <body>
#   <div>
#     <p>라운드 사각형 틀 이미지</p>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="roundrec">
#   </div>
#   <div>
#     <p>원형 틀 이미지</p>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="circle">
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_14.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 썸네일 이미지 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_14.css"/>
# </head>
# <body>
#   <div>
#     <p>썸네일 이미지</p>
#     <a href="https://probemedia.github.io/studyhtml5/images/tree.png" target="_blank">
#       <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="thumnail">
#     </a>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_15.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 반응형 이미지 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_15.css"/>
# </head>
# <body>
#   <div>
#     <p class="restxt">반응형 이미지</p>
#     <img src="https://probemedia.github.io/studyhtml5/images/tree.png" class="resimg">
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_16.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 반응형 이미지 갤러리 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_16.css"/>
# </head>
# <body>
#   <div>
#     <h1 class="center">안시성 전투</h1>
#     <h3 class="center">초등학교 1학년의 작품</h3>
#   </div>
#   <div>
#     <a href="https://probemedia.github.io/studyhtml5/images/ansi1.png" target="_blank" class="responsive">
#       <img src="https://probemedia.github.io/studyhtml5/images/ansi1.png">
#     </a>
#     <a href="https://probemedia.github.io/studyhtml5/images/ansi2.png" target="_blank" class="responsive">
#       <img src="https://probemedia.github.io/studyhtml5/images/ansi2.png">
#     </a>
#     <a href="https://probemedia.github.io/studyhtml5/images/ansi3.png" target="_blank" class="responsive">
#       <img src="https://probemedia.github.io/studyhtml5/images/ansi3.png">
#     </a>
#     <a href="https://probemedia.github.io/studyhtml5/images/ansi4.png" target="_blank" class="responsive">
#       <img src="https://probemedia.github.io/studyhtml5/images/ansi4.png">
#     </a>
#     <a href="https://probemedia.github.io/studyhtml5/images/ansi5.png" target="_blank" class="responsive">
#       <img src="https://probemedia.github.io/studyhtml5/images/ansi5.png">
#     </a>
#     <a href="https://probemedia.github.io/studyhtml5/images/ansi6.png" target="_blank" class="responsive">
#       <img src="https://probemedia.github.io/studyhtml5/images/ansi6.png">
#     </a>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_17.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 이미지에 텍스트 추가 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_17.css"/>
# </head>
# <body>
#   <div class="relative">
#     <img src="https://probemedia.github.io/studyhtml5/images/ansi1.png">
#     <p class="topleft">용감한 고구려군</p>
#   </div>
#   <div class="relative">
#     <img src="https://probemedia.github.io/studyhtml5/images/ansi6.png">
#     <p class="topleft">당나라 잡병</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_18.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 폴라로이드 이미지 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_18.css"/>
# </head>
# <body>
#   <div>
#     <img src="https://probemedia.github.io/studyhtml5/images/ansi1.png" class="resimg">
#     <p class="restxt">용감한 고구려군</p>
#   </div>
#   <div>
#     <img src="https://probemedia.github.io/studyhtml5/images/ansi6.png" class="resimg">
#     <p class="restxt">당나라 잡병</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_19.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 이미지 모달 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_19.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch04/css3_19.js"></script>
# </head>
# <body>
#   <div id="display">
#     <img id="img1" src="https://probemedia.github.io/studyhtml5/images/sj.png" alt="십장생도 - 유치원생(7세) 작품">
#   </div>
#
#   <div id="dialog" class="modal">
#     <p id="closebtn" class="closebutton">x</p>
#     <img id="modalimg" class="modalcontent">
#     <div id="imgcaption" class="caption"></div>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_20.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 웹 폰트 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_20.css"/>
# </head>
# <body>
#   <div>
#     <p class="webfont">Marvel 히어로즈</p>
#     <p>DC 히어로즈</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--css3_21.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>CSS3 다단 사용 연습</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch04/css3_21.css"/>
# </head>
# <body>
#   <div class="multicolumn">모바일 기기는 초고속 무선 인터넷의 보급으로 다양한 콘텐츠를 PC수준으로 소비할 수 있는 개인 전용 미디어로 진화했다. 국내 모바일 콘텐츠는 모바일 웹 및 모바일 앱을 기반으로 이용자들이 계속 증가하고 있다.
#    모바일 서비스는 모바일 인터넷 서비스를 포함한 개념으로 무선단말기로 각 사업자가 제공하는 포탈이나 서비스 망에서 모바일 콘텐츠를 사용할 수 있게 해주는 비즈니스이며, 모바일 컨텐츠는 모바일 인터넷 망에서 제공되는 유무형의 가치가 있는 서비스로 텍스트, 음악, 비디오, 각종 영상 등을 포함하는 멀티미디어의 총 집합체이다. 여기서 콘텐츠(Contents)는 각종 유무선 통신 네트워크를 통해 제공되는 디지털 정보를 통칭하는 용어로 인터넷이나 PC통신 등을 통해 제공되는 각종프로그램이나 정보 내용물, 영화, 음악, 게임 소프트웨어 등을 말한다.
#    초기의 모바일 컨텐츠는 전송 용량, 전송 속도, 화면 크기, 사용자 인터페이스가 유선 인터넷에 비해 제한적이어서 텍스트 기반의 정보가 주를 이루었다. 현재는 모바일 인터넷 기술의 발전으로 다양한 형태의 자료가 실시간으로 전달되어, 사용자 위치에 따른 위치 정보서비스와 발전된 모바일 기기을 통해 개인맞춤 서비스가 가능하게 되었다.
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--.html-->

# %% [markdown]
# ### 05 부트스트랩

# %%
# %%html
# <!--btsp01.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
#   <div class="container p-5 my-5 bg-primary text-white">
#     <h1>부트스트랩 연습</h1>
#     <p>처음 사용하는 부트스트랩</p>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp02.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container-fluid">
#   <div class="row mt-5">
#     <div class="col-sm-3 p-3 bg-primary text-white">메뉴1</div>
#     <div class="col-sm-3 p-3 bg-dark text-white">메뉴2</div>
#     <div class="col-sm-3 p-3 bg-primary text-white">메뉴3</div>
#     <div class="col-sm-3 p-3 bg-dark text-white">메뉴4</div>
#   </div>
#   <div class="row mt-5">
#     <div class="col-sm-4 p-3 bg-primary text-white">그리드1</div>
#     <div class="col-sm-4 p-3 bg-dark text-white">그리드2</div>
#     <div class="col-sm-4 p-3 bg-primary text-white">그리드3</div>
#   </div>
#   <div class="row mt-5">
#     <div class="col-sm-4 p-3 bg-primary text-white">구역1</div>
#     <div class="col-sm-8 p-3 bg-dark text-white">구역2</div>
#   </div>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp03.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container">
#   <div class="row">
#     <div class="col-sm-4">
#       <p class="text-muted">text-muted</p>
#       <p class="text-primary">text-primary</p>
#       <p class="text-success">text-success</p>
#       <p class="text-info">text-info</p>
#     </div>
#     <div class="col-sm-4">
#       <p class="text-warning">text-warning</p>
#       <p class="text-danger">text-danger</p>
#       <p class="text-secondary">text-secondary</p>
#       <p class="text-white">text-white</p>
#     </div>
#     <div class="col-sm-4">
#       <p class="text-dark">text-dark</p>
#       <p class="text-body">text-body</p>
#       <p class="text-light">text-light</p>
#     </div>
#   </div>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp04.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container">
#   <div class="row">
#     <div class="col-sm-6">
#       <p class="bg-primary text-dark">bg-primary</p>
#       <p class="bg-success text-dark">bg-success</p>
#       <p class="bg-info text-dark">bg-info</p>
#       <p class="bg-warning text-dark">bg-warning</p>
#     </div>
#     <div class="col-sm-6">
#       <p class="bg-danger text-dark">bg-danger</p>
#       <p class="bg-secondary text-dark">bg-secondary</p>
#       <p class="bg-dark text-white">bg-dark</p>
#       <p class="bg-light text-dark">bg-light</p>
#     </div>
#   </div>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp05.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container mt-3">
#   <img src="https://probemedia.github.io/studyhtml5/images/ansi1.png" class="rounded">
#   <img src="https://probemedia.github.io/studyhtml5/images/ansi2.png" class="rounded-circle">
#   <img src="https://probemedia.github.io/studyhtml5/images/ansi3.png" class="img-thumbnail">
#   <img src="https://probemedia.github.io/studyhtml5/images/ansi4.png" class="float-start">
#   <img src="https://probemedia.github.io/studyhtml5/images/ansi5.png" class="float-end">
#   <img src="https://probemedia.github.io/studyhtml5/images/ansi6.png" class="mx-auto d-block">
#   <img src="https://probemedia.github.io/studyhtml5/images/sj.png" class="img-fluid">
#  </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp06.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container mt-3">
#   <button class="btn">btn</button>
#   <button class="btn btn-primary">btn btn-primary</button>
#   <button class="btn btn-secondary">btn btn-secondary</button>
#   <button class="btn btn-success">btn btn-success</button>
#   <button class="btn btn-info">btn btn-info</button>
#   <button class="btn btn-danger">btn btn-danger</button>
#   <button class="btn btn-dark">btn btn-dark</button>
#   <button class="btn btn-light">btn btn-light</button>
#   <button class="btn btn-link">btn btn-link</button>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp07.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="p-5 bg-primary text-white text-center">
#   <h1>안시성 전투</h1>
#   <p>고구려와 당나라의 전투 : 고구려 승</p>
# </div>
#
# <nav class="navbar navbar-expand-sm bg-dark navbar-dark">
#   <div class="container-fluid">
#     <ul class="navbar-nav">
#       <li class="nav-item">
#         <a class="nav-link active" href="#">전투개요</a>
#       </li>
#       <li class="nav-item">
#         <a class="nav-link" href="#">전투상황</a>
#       </li>
#       <li class="nav-item">
#         <a class="nav-link" href="#">고찰</a>
#       </li>
#     </ul>
#   </div>
# </nav>
#
# <div class="container mt-5">
#   <div class="row">
#     <div class="col-sm-4">
#       <h2>안시성 고구려군 사진</h2>
#       <h5>엣지있는 고구려군</h5>
#       <div><img src="https://probemedia.github.io/studyhtml5/images/ansi1.png"></div>
#       <p>전투시에도 멋진 모습을 잃지않는 용맹한 고구려의 병사들</p>
#       <h3 class="mt-4">안시성 이모저모</h3>
#       <p>복지정책</p>
#       <ul class="nav nav-pills flex-column">
#         <li class="nav-item">
#           <a class="nav-link active" href="#">양만춘 장군님의 하루</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="#">오늘의 고구려군 식당메뉴</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="#">신참병의 병영 일기</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link disabled" href="#">당나라군 실상</a>
#         </li>
#       </ul>
#       <hr class="d-sm-none">
#     </div>
#     <div class="col-sm-8">
#       <h2>오늘의 전투1</h2>
#       <h5>양만춘 장군님</h5>
#       <div><img src="https://probemedia.github.io/studyhtml5/images/ansi2.png"></div>
#       <p>오늘도 성곽에서</p>
#
#       <h2 class="mt-5">오늘의 전투1</h2>
#       <h5>고구려병사와 당나라병사의 일기토</h5>
#       <div><img src="https://probemedia.github.io/studyhtml5/images/ansi3.png"></div>
#       <p>고구려 병사의 멋진 모습</p>
#     </div>
#   </div>
# </div>
#
# <div class="mt-5 p-4 bg-dark text-white text-center">
#   <p>안시성 찾아오시는 길</p>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp08.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container-fluid text-bg-dark mt-0">
#   <h3>캐러셀(carousel) 예제</h3>
#   <p>캐러셀 만들고 제어하기.</p>
# </div>
# <!-- 캐러셀 -->
# <div id="c1" class="carousel slide" data-bs-ride="carousel">
#
#   <!-- 캐러셀의 각각의 슬라이드의 인디케이터를 지정 -->
#   <div class="carousel-indicators">
#     <button data-bs-target="#c1" data-bs-slide-to="0" class="active"></button>
#     <button data-bs-target="#c1" data-bs-slide-to="1"></button>
#     <button data-bs-target="#c1" data-bs-slide-to="2"></button>
#   </div>
#
#   <!-- 캐러셀 슬라이드 쇼 -->
#   <div class="carousel-inner">
#     <div class="carousel-item active">
#       <img src="https://probemedia.github.io/studyhtml5/images/pic1_w.png" class="d-block" style="width:100%;">
#     </div>
#     <div class="carousel-item">
#       <img src="https://probemedia.github.io/studyhtml5/images/pic2_w.png" class="d-block" style="width:100%;">
#     </div>
#     <div class="carousel-item">
#       <img src="https://probemedia.github.io/studyhtml5/images/pic3_w.png" class="d-block" style="width:100%;">
#     </div>
#   </div>
#
#   <!-- 왼쪽/오른쪽 이동 버튼 -->
#   <button class="carousel-control-prev" data-bs-target="#c1" data-bs-slide="prev">
#     <span class="carousel-control-prev-icon"></span>
#   </button>
#   <button class="carousel-control-next" data-bs-target="#c1" data-bs-slide="next">
#     <span class="carousel-control-next-icon"></span>
#   </button>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp09.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container mt-3">
#   <h3>모달 이미지 예제</h3>
#   <p>이미지클릭.</p>
#   <img src="https://probemedia.github.io/studyhtml5/images/sj.png" class="btn" data-bs-toggle="modal" data-bs-target="#md1" width="80px" height="50px">
# </div>
#
# <!-- 이미지 모달 -->
# <div class="modal" id="md1">
#   <div class="modal-dialog modal-dialog-centered">
#     <div class="modal-content">
#
#       <!-- 모달 헤더 -->
#       <div class="modal-header">
#         <h4 class="modal-title">유치원생이 그린 십장생도</h4>
#         <button class="btn-close" data-bs-dismiss="modal"></button>
#       </div>
#
#       <!-- 모달 바디 -->
#       <div class="modal-body">
#         <img src="https://probemedia.github.io/studyhtml5/images/sj.png" alt="sj">
#       </div>
#
#       <!-- 모달 푸터 -->
#       <div class="modal-footer">
#         <button class="btn btn-danger" data-bs-dismiss="modal">닫기</button>
#       </div>
#
#     </div>
#   </div>
# </div>
# </body>
# </html>

# %%
# %%html
# <!--btsp010.html-->
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/css/bootstrap.min.css" rel="stylesheet">
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
# <title>bootstrap test</title>
# </head>
# <body>
# <div class="container mt-3">
#   <h3>팝오버 예제</h3>
#   <button class="btn btn-primary" data-bs-toggle="popover" title="팝오버 연습"
#     data-bs-content="[누르세요]버튼을 다시 누르면 닫힙니다.">누르세요</button>
#   <button class="btn btn-dark" data-bs-toggle="popover" title="팝오버 연습"
#     data-bs-trigger="hover" data-bs-content="호버기능">마우스포인터를 여기에</button>
# </div>
#
# <script>
# var ptList = [].slice.call(document.querySelectorAll('[data-bs-toggle="popover"]'))
# var poList = ptList.map(function (ptEl) {
#   return new bootstrap.Popover(ptEl)
# })
# </script>
# </body>
# </html>

# %%
# %%html
# <!--.html-->

# %% [markdown]
# ## 5장 동작을 처리하는 자바스크립트와 제이쿼리

# %% [markdown]
# ### 01 자바스크립트 개요

# %%
# %%html
# <!--js_05_01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var var1 = 1;
#     var str1 = "test";
#     var status = true;
#     document.write("데이터타입 예제 - 숫자타입, 문자열타입, 불린타입 <br>");
#     document.write(var1 + ", " + str1 + ", " + status);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var v1 = 5;
#     var v2 = {id: "aaaa", pass: "passwd", method1: function(){return 1;}};
#     document.write("데이터타입 예제 - 객체<br>");
#     document.write(v1 + ", " + v2 + "<br>");
#     document.write(v2.id + ", " + v2.pass + "<br>");
#     document.write(v2.method1() + "<br>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var arr1 = [1, 2, 3];
#     document.write("데이터타입 예제 - 배열<br>");
#     document.write(arr1 + "<br>");
#     document.write(arr1[0] + ", ", arr1[arr1.length-1]);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var func1 = function(x){
#     	var y = x + 5;
#     	return x + y;};
#     document.write("데이터타입 예제 - 함수<br>");
#     document.write(func1(5));
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var v1 = 3
#     var v2 ="test"
#     var v3 = {id: "aaaa"};
#     var v4 = ["a", "b"];
#     var v5 = function(){return 1;};
#
#     document.write("데이터타입 예제 - 변수선언<br>");
#     document.write(v1 + "<br>");
#     document.write(v2 + "<br>");
#     document.write(v3+ "<br>");
#     document.write(v4+ "<br>");
#     document.write(v5() + "<br>");
#   </script>
# </body>
# </html>

# %% [markdown]
# ### 02 제어문

# %%
# %%html
# <!--js_05_06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var i = 5;
#     var s = 10;
#
#     if(i < 10){
#       s += i;
#     }else{
#       s -= i
#     }
#
#     document.write("제어문 예제 - 기본 if문<br>");
#     document.write("s변수의 값 : " + s +"<br/>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_07.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var i = 5;
#     var s = 10;
#
#     if(i < 10){
#       s += i;
#     }
#
#     document.write("제어문 예제 - 조건 만족할때만 처리가 있는 if문<br>");
#     document.write("s변수의 값 : " + s +"<br/>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_08.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var x = 10;
#     var str1 = "";
#
#     if(x > 0){
#       str1 = "양수";
#     }else if(x === 0){
#       str1 = "0";
#     }else{
#       str1 = "음수";
#     }
#
#     document.write("제어문 예제 - 다중 if문<br>");
#     document.write(str1);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_09.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var a = 10;
#
#     var v1 = (a > 5)? 5 : a;
#
#     document.write("제어문 예제 - 조건연산자<br>");
#     document.write(v1);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_10.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     document.write("제어문 예제 - for문<br>");
#     for(var x = 0; x < 5; x++){
#     	document.write(x + "<br>");
#     }
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_11.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var objName = {name: "김왕쌍", subName : "kingdora"};
#
#     document.write("제어문 예제 : for-in문<br>");
#     for (var v1 in objName ) {
#       document.write(v1 + " : " + objName[v1] + "<br>");
#     }
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_12.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var objName = [{name: "김태형", subName : "taetae"},
#     	           {name: "김연탄", subName : "tan"}];
#
#     document.write("제어문 예제 : for-of문<br>");
#     for(let obj1 of objName) {
#       for(var v1 in obj1){
#         document.write(v1 + " : " + obj1[v1] + "<br>");
#       }
#     }
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_13.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var str = "";
#
#     for(var i = 0; i < 10; i++){
#       if(i == 5) break;
#       str += i + " ";
#     }
#
#     document.write("제어문 예제 : break문<br>");
#     document.write("결과 : " + str);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_14.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var str = "";
#
#     for(var i = 0; i < 10; i++){
#       if(i == 5) continue;
#       str += i + " ";
#     }
#
#     document.write("제어문 예제 : continue문<br>");
#     document.write("결과 : " + str);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_15.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     function add(x, y) { return x + y;}
#
#     document.write("함수 예제 : 함수선언문으로 함수 정의<br>");
#     document.write(add(5, 3));
#   </script>
# </body>
# </html>

# %% [markdown]
# ### 03 함수와 객체

# %%
# %%html
# <!--js_05_16.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var add = function(x, y){ return x + y;};
#
#     document.write("함수 예제 : 함수표현식으로 함수 정의<br>");
#     document.write(add(5, 3));
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_17.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var v1 = function(x){return x + 10;};
#
#     document.write("함수 예제 : 익명함수 정의<br>");
#     document.write(v1(9));
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_18.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     document.write("함수 예제 : 즉시실행함수 정의<br>");
#     (function() {
# 	  var x = "Hello!!";
# 	  document.write(x);
# 	})();
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_19.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var counter = 0;
#
#     function add1(){ return counter += 1;}
#
#     document.write("함수 예제 : 카운터변수를 전역변수로 선언<br>");
#     document.write(add1(), "<br>");
#     document.write(add1(), "<br>");
#     document.write(add1(), "<br>");
#     document.write(counter)
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_20.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     function add1(){
# 	    var counter = 0;
# 	    return counter += 1;
# 	 }
#
#    document.write("함수 예제 : 카운터변수를 지역변수로 선언<br>");
#    document.write(add1(), "<br>");
# 	 document.write(add1(), "<br>");
# 	 document.write(add1(), "<br>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_21.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var add1 = (function(){
# 	    var counter = 0;
# 	    return function(){counter += 1; return counter;}
# 	})();
#
#   document.write("함수 예제 : 클로저를 사용한 카운터변수를 딜레마 처리<br>");
#   document.write(add1(), "<br>");
# 	document.write(add1(), "<br>");
# 	document.write(add1(), "<br>");
# 	document.write(counter);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_22.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var objStudent = {name: "kingdora",
#     		          major: "computer science",
#     		          to_do: function(m){return m + " studing";}};
#
#     document.write("객체 예제 : 객체생성, 프로퍼티 접근<br>");
#     document.write(objStudent.name + "<br>");
#     document.write(objStudent.to_do(objStudent.major) + "<br>");
#
#     objStudent.major = "electronics engineering"; // 프로퍼티값 변경
#     objStudent.age = 22;  // 새 프로퍼티 생성
#     document.write(objStudent.major + "<br>");
#     document.write(objStudent.age + "<br>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_23.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var object1 = {
# 		  number1: 1230,
# 		  string1: "yeontan",
# 		  boolean1: true,
# 		  array1: [52, 273, 103, 32],
# 		  method1: function(){return 1;}
# 	};
#
#     document.write("객체 예제 : 객체 프로퍼티 반복 접근<br>");
#     for(var x1 in object1){
# 	  document.write(x1, " : ", object1[x1], "<br>");
# 	}
# 	document.write("object1.method1()메소드 실행 : " + object1.method1());
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_24.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var objName = {name: "김왕쌍",
#     		       subName: "kingdora"};
#
#     document.write("객체 예제 : 객체 프로퍼티 제거<br>");
#     document.write("objName객체 프로퍼티 출력<br>");
#     for(var v1 in objName) {
#        document.write(v1 + " : " + objName[v1] + "<br>");
#     }
#
#     delete objName.subName;  // objName객체의 subName프로퍼티 제거
#
#     document.write("<br>subName프로퍼티 제거 후 objName객체 프로퍼티 출력<br>");
#     for(var v1 in objName) {
#     	document.write(v1 + " : " + objName[v1] + "<br>");
#     }
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_25.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var obj1 = {name: "yeontan"};
#     var obj2 = {name: "yeontan"};
#     var obj3 = obj1;
#
#     document.write("객체 예제 : 객체 레퍼런스 비교<br>");
#     if(obj1 == obj3)  // 같은 객체
#     	document.write("obj1과 obj3은 같은 객체<br>");
#     else
#     	document.write("obj1과 obj3은 다른 객체<br>");
#
#     if(obj1 == obj2)  // 다른 객체
#     	document.write("obj1과 obj2는 같은 객체<br>");
#     else
#     	document.write("obj1과 obj2는 다른 객체<br>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_26.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var str1 = "yeontan";
#     var str2 = "yeontan";
#     var obj1 = {name: "yeontan"};
#     var obj2 = {name: "yeontan"};
#
#     document.write("객체 예제 : 객체 내용 비교<br>");
#     if(str1 === str2)  // 내용이 같은 문자열
#     	document.write("str1, str2 문자열의 내용이 같다<br>");
#     else
#     	document.write("str1, str2 문자열의 내용이 다르다<br>");
#
#     if(JSON.stringify(obj1) === JSON.stringify(obj2))  // 내용이 같은 객체
#     	document.write("obj1, obj2객체는 객체의 내용이 같다<br>");
#     else
#     	document.write("obj1, obj2객체는 객체의 내용이 다르다<br>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_27.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var PlayerCharacter = function(name){
# 	    this.name = name;
# 	};
#
# 	var pc = new PlayerCharacter("warrior");
#
# 	document.write("객체 예제 : 생성자 함수선언<br>");
# 	document.write(pc.name);
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_28.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     var PlayerCharacter = function(name){  // 생성자함수 선언
# 	    this.name = name;  // 프로퍼티 선언
# 	    this.getName = function(){return name;}  // 메소드 선언
# 	};
#
# 	var pc = new PlayerCharacter("basic");
#
# 	document.write("객체 예제 : 생성자 함수에 메소드 작성<br>");
# 	document.write(pc.getName(),"<br>");
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_29.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <script>
#     function Student(name, korean, math) {  // 생성자 함수 선언
# 	  this.name = name;
# 	  this.korean = korean;
# 	  this.math = math;
# 	}
#
# 	Student.prototype.getSum = function(){  // 생성자 함수밖에서 메소드 추가
# 	  return this.korean + this.math;
# 	};
#
# 	var s1 = new Student("김연탄", 100, 100)  // s1객체생성
#
# 	document.write("객체 예제 : 프로토타입에 메소드 작성<br>");
# 	document.write(s1.name, " : ", s1.getSum());
#   </script>
# </body>
# </html>

# %%
# %%html
# <!--js_05_30.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>JavaScript test</title>
# </head>
# <body>
#   <p>객체 예제 : DOM구조의 태그내용에 접근</p>
#   <div id="result"></div>
#   <div id="result2">1111</div>
#
#   <script>
#     // 태그 내용에 접근해서 태그 내용을 변경
#     document.getElementById("result").innerHTML = "<p>연습</p>"
#   </script>
# </body>
# </html>

# %% [markdown]
# ### 04 제이쿼리를 사용한 태그제어와 Ajax

# %%
# %%html
# <!--jq01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>제이쿼리 테스트 페이지</title>
# <style>
#   div#displayArea{
#     width  : 200px;
#     height : 200px;
#     border : 5px double #6699FF;
#   }
# </style>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script>
#   $(document).ready(function(){
# 	  $("button").click(function(){
# 	    $("#displayArea").html("<img src='https://probemedia.github.io/studyhtml5/images/p2_s.png' border='0'/>");
# 	  });
#   });
# </script>
# </head>
# <body>
#   <div id="displayArea">이곳의 내용 변경 </div>
#   <button>표시</button>
# </body>
# </html>

# %%
# %%html
# <!--jq02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>제이쿼리 실렉터 예제</title>
# <link rel="stylesheet" href="jq02.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq02.js"></script>
# </head>
# <body>
#   <div id="picArea">
#     <img id="pic1" class="c1" src="https://probemedia.github.io/studyhtml5/images/picture1.png">
#     <img id="pic2" class="c2" src="https://probemedia.github.io/studyhtml5/images/picture2.png">
#     <img id="pic3" class="c1" src="https://probemedia.github.io/studyhtml5/images/picture3.png">
#     <img id="pic3" class="c2" src="https://probemedia.github.io/studyhtml5/images/picture4.png">
#   </div>
#   <div id="btnArea">
#     <button id="b1">id="pic1"인 이미지 숨기기</button>
#     <button id="b2">class="c1"인 이미지 숨기기</button>
#     <button id="b3">모든 이미지 숨기기</button><br>
#     <button id="b4">숨기기 취소</button>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--jq03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery 실렉터와 메소드를 사용한 엘리먼트의 내용변경</title>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq03_2.js"></script>
# </head>
# <body>
#   <p>이미지표시</p>
#   <button id="b1">버튼레이블 변경</button>
#   <div id="display"></div>
#   <button id="b2">버튼</button>
# </body>
# </html>

# %%
# %%html
# <!--jq04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery 이벤트처리 - 마우스 이벤트</title>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq04.js"></script>
# </head>
# <body>
#   <p>마우스 포인터를 여기에!!!</p>
#   <button>더블클릭하시구려.</button>
# </body>
# </html>

# %%
# %%html
# <!--jq05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery 이벤트처리 - 키보드 이벤트</title>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq05.js"></script>
# </head>
# <body>
#   <p id="p1">아무키나 눌렀다 놓으세요</p>
# </body>
# </html>

# %%
# %%html
# <!--jq06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery 이벤트처리 - 폼 이벤트</title>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq06.js"></script>
# </head>
# <body>
#   <form>
#     <label for="idx">아이디</label>
#     <input type="text" id="idx" name="idx"><br>
#     <label for="name">이름</label>
#     <input type="text" id="name" name="name"><br>
#   </form>
# </body>
# </html>

# %%
# %%html
# <!--jq07.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery 이벤트처리 - 도큐먼트 / 윈도우 이벤트</title>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq07_2.js"></script>
# </head>
# <body>
#   <div id="result"></div>
# </body>
# </html>

# %%
# %%html
# <!--jq08.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery Ajax메소드 사용 예제 - load()메소드</title>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq08_2.js"></script>
# </head>
# <body>
#   <button id="pro">결과</button>
#   <div id="result"></div>
# </body>
# </html>

# %%
# %%html
# <!--jq09.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery Ajax메소드 사용 예제 - load()메소드 응답처리</title>
# <link rel="stylesheet" href="main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq09_2.js"></script>
# </head>
# <body>
#   <button id="pro">결과</button>
#   <div id="result"></div>
# </body>
# </html>

# %%
# %%html
# <!--jq10.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>jQuery Ajax메소드 사용 예제 - $.ajax() 메소드</title>
# <link rel="stylesheet" href="main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch05/jq10.js"></script>
# </head>
# <body>
#   <button id="pro">결과</button>
#   <div id="result"></div>
# </body>
# </html>

# %%
# %%html
# <!--.html-->

# %% [markdown]
# ## 6장 애니메이션을 만드는 캔버스

# %% [markdown]
# ### 01 자바스크립트로 Canvas제어

# %%
# %%html
# <!--canvas01.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>캔버스 영역 만들기</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch06/main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# </head>
# <body>
#   <div id="s1">
#     <canvas id="canvas1" width="300" height="200">
#       웹 브라우저가 HTML5 캔버스를 지원하지 않습니다.
#     </canvas>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--canvas02.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>캔버스 영역에 도형 그리기</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch06/main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch06/canvas02.js"></script>
# </head>
# <body>
#   <div id="s2">
#     <canvas id="canvas1" width="450" height="250">
#       웹 브라우저가 HTML5 캔버스를 지원하지 않습니다.
#     </canvas>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--canvas03.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>캔버스 영역에 패턴 그리기</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch06/main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch06/canvas03_2.js"></script>
# </head>
# <body>
#   <div id="s2">
#     <canvas id="canvas1" width="250" height="150">
#       웹 브라우저가 HTML5 캔버스를 지원하지 않습니다.
#     </canvas>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--canvas04.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>캔버스 영역에 이미지 그리기</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch06/main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch06/canvas04_2.js"></script>
# </head>
# <body>
#   <div id="s2">
#     <canvas id="canvas1" width="300" height="200">
#       웹 브라우저가 HTML5 캔버스를 지원하지 않습니다.
#     </canvas>
#   </div>
# </body>
# </html>

# %% [markdown]
# ### 02 캔버스를 사용한 애니메이션

# %%
# %%html
# <!--canvas05.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>이미지 롤링(파노라마) 애니메이션</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch06/main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch06/canvas05_2.js"></script>
# </head>
# <body>
#   <div id="s2">
#     <canvas id="canvas1" width="300" height="100">
#       웹 브라우저가 HTML5 캔버스를 지원하지 않습니다.
#     </canvas>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--canvas06.html-->
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# <title>아날로그시계 애니메이션</title>
# <link rel="stylesheet" href="https://probemedia.github.io/studyhtml5/ch06/main.css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.3/jquery.min.js"></script>
# <script src="https://probemedia.github.io/studyhtml5/ch06/canvas06.js"></script>
# </head>
# <body>
#   <div id="s2">
#     <canvas id="canvas1" width="200" height="200">
#       웹 브라우저가 HTML5 캔버스를 지원하지 않습니다.
#     </canvas>
#   </div>
# </body>
# </html>

# %%
# %%html
# <!--.html-->

# %% [markdown]
# ## 추가
